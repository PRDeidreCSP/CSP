# %%
from jupyter_server.auth import passwd

{
  "cells": [
    {
      "cell_type": "markdown",
      "id": "d86f5cdb",
      "metadata": {

      },
      "source": [
        "### Exercicio 1: Operadores Aritméticos\n",
        "\n",
        "Calcula a área e perímetro dun rectángulo:\n",
        "- Pide ao usuario base e altura.\n",
        "- Calcula área.\n",
        "- Calcula perímetro.\n",
        "- Utiliza `//` e `%`.\n",
        "- Amosa os resultados utilizando diferentes formatos de cadeas."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "3771e266",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"

b=int(input("introduce la base del triangulo:"))
a=int(input("intoduce la altura del triangulo:"))


if b >0 and a >0:
    area=b*a
    p= 2*(b+a)

    print(f"el area es {a}")
    print(f"el perimetro es {p}")
else:
    print("la base y la altura es 0, no puedo calcularlo")
      ]
    },
    {
      "cell_type": "markdown",
      "id": "9b645d81",
      "metadata": {

      },
      "source": [
        "---\n",
        "\n",
        "### Exercicio 2: Operadores de Asignación\n",
        "\n",
        "Simula unha conta bancaria:\n",
        "- Saldo inicial: 1000\n",
        "- Usa += para depositar 500\n",
        "- Usa -= para retirar 300\n",
        "- Usa *= para aplicar interés do 10%\n",
        "- Usa /= para dividir entre 2 (metade para aforros)\n",
        "- Amosa saldo despois de cada operación\n",
        "- Utiliza diferentes formatos de cadeas."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "016fb80b",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"

       saldo = 1000
print(f"Saldo inicial: {saldo} €")

# Depositar 500
deposito = 500
if deposito > 0:
    saldo += deposito
    print(f"Depósito realizado. Saldo: {saldo} €")

# Retirar 300
retirada = 300
if retirada <= saldo:
    saldo -= retirada
    print(f"Retirada realizada. Saldo: {saldo} €")
else:
    print("Saldo insuficiente para retirar.")

# Aplicar interes
if saldo > 0:
    saldo *= 1.10
    print(f"Interes aplicado. Saldo: {saldo:.2f} €") #para tener 2 decimales*
else:
    print("No se aplica interes porque o saldo é negativo.")

# Dividir entre 2
if saldo > 0:
    saldo /= 2
    print("Saldo final para ahorros: {:.2f} €".format(saldo)) #format puede reemplazar {} , es posible que pueda contener varios* {}
else:
    print("Non hay saldo para dividir.")

      ]
    },
    {
      "cell_type": "markdown",
      "id": "2394df87",
      "metadata": {

      },
      "source": [
        "---\n",
        "\n",
        "### Exercicio 3: Operadores de Comparación\n",
        "\n",
        "Sistema de verificación de acceso:\n",
        "- Pide idade e se é socio ou non.\n",
        "- Verifica se idade \u003E= 18 e \u003C= 65\n",
        "- Verifica se idade \u003C\u003E 0\n",
        "- Usa todos estes operadores: \u003E, \u003C, \u003E=, \u003C=, ==, !=\n",
        "- O mesmo: utiliza diferentes formatos de cadeas para amosar os resultados."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "727f101e",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"

edad= int(input("¿cual es tu edad?: "))
socio= str(intput("¿eres socio?"))

if edad != 0:
    if edad >= 18 and edad <= 65 :
        print(f"edad valida esta dentro del rango 18 y 65, es {edad}")
        elif edad < 18:
        print("tienes menos de 18 ")
        elif edad > 65:
        print("tienes mas de 65 ")
    else
        print("la edad no puede ser CERO")
:
if socio == "si"
    print("accceso permitido")
else
    print(acceso denegado)



      ]
    },
    {
      "cell_type": "markdown",
      "id": "c3c24d51",
      "metadata": {

      },
      "source": [
        "---\n",
        "\n",
        "### Exercicio 4: Operadores Lóxicos\n",
        "\n",
        "Determina se un ano é bisesto:\n",
        "- Divisible entre 4.\n",
        "- Non divisible entre 100, excepto se é divisible entre 400.\n",
        "- Non encadenes condicionais senón condicións.\n",
        "- Exemplo: 2024 (bisesto), 1900 (non bisesto), 2000 (bisesto)."
      ]


     },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "b05fda3d",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"
ano=int(input("introduce un año:" ))

if (ano % 4 == 0) and (ano % 100 != 0 or ano % 400 == 0):
    print("bisisesto")
else:
    print("non bisisesto")



      ]
    },
    {
      "cell_type": "markdown",
      "id": "06ab3c1b",
      "metadata": {

      },
      "source": [
        "---\n",
        "\n",
        "### Exercicio 5: Operadores de Identidade\n",
        "\n",
        "Analiza diferenzas entre == e is:\n",
        "- Crea dúas listas (lista1, lista2) iguais: [1, 2, 3]\n",
        "- Crea unha variable (lista3) que apunte lista2, por exemplo.\n",
        "- Explica resultados de comparar `==` e `is`."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "4eb10f0d",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"

lista1 =[1, 2, 3]
lista2 =[1, 2, 3]
lista3 = lista2


# Comparación con ==   compara el contenido de las listas
print("Comparación con ==")
print(f"lista1 == lista2 ? {lista1 == lista2}")
print(f"lista2 == lista3 ? {lista2 == lista3}")

# Comparación con is - compara si apuntan al mismo objeto en la memoria, haciendo que aunque sean iguales en contenido , son finalmente objetos distintos.
print("Comparación con is")
print(f"lista1 is lista2 ? {lista1 is lista2}")
print(f"lista2 is lista3 ? {lista2 is lista3}")
      ]
    },
    {
      "cell_type": "markdown",
      "id": "68526c81",
      "metadata": {

      },
      "source": [
        "---\n",
        "\n",
        "### Exercicio 6: Operadores de Pertenza\n",
        "\n",
        "Buscador de vogais en texto:\n",
        "- Pide unha frase ao usuario.\n",
        "- Usa `in` para verificar se contén cada vogal.\n",
        "- Usa `not in` para verificar se non contén números.\n",
        "- Conta cantas vogais diferentes ten."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "4a5ef3b8",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"

frase=(input('escribe uma frase: '))
vocales="aeiou"
contador = 0

for letra in frase:
    if letra in vocales:
        contador=contador + 1
print(f"Número total de vocales: {contador}")

if not any(n in frase for n in "0123456789"):
        print(f"la frase  no contiene números  y es {frase}")
else:
        print(f"la frase contiene números  y es {frase}")







      ]
    },
    {
      "cell_type": "markdown",
      "id": "6f288b78",
      "metadata": {

      },
      "source": [
        "---\n",
        "\n",
        "### Exercicio 7: Operadores de Cadeas\n",
        "\n",
        "Manipulación de strings:\n",
        "- Concatena o teu nome, apelido e o nome do módulo (CSP).\n",
        "- Repite un patrón 3 veces.\n",
        "- Verifica se \"ola\" está nunha frase.\n",
        "- Extrae subcadeas con `slicing`.\n",
        "- Converte a maiúsculas e a minúsculas."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "b38188c1",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"

nome="Deidre"
apelido="Pizarro"
modulo="Contornas e sintaxe en Python"
print(f"me llamo {nome} , {apelido} y estoy matriculada en el modulo de {modulo}")

for i in range(3):
    print("Deidre")

frase="hola me llamo Deidre"
palabra="hola"



for p in frase.split():
    if p == palabra:
        print("la palabra hola existe en en la frase")
    else:
        print("la palabra no existe")

subcadena1 = frase[:4]
print(subcadena1)

subcadena3 = frase[4:]
print(subcadena3)


subcadena3 = frase[::2]
print(subcadena3)

print(frase.upper())
print(frase.lower())

           ]
    },
    {
      "cell_type": "markdown",
      "id": "af0d0f7c",
      "metadata": {

      },
      "source": [
        "---\n",
        "\n",
        "### Exercicio 8: Walrus\n",
        "\n",
        "Validador de contrasinal con walrus:\n",
        "- Pide contrasinal ata que cumpra requisitos.\n",
        "- Lonxitude \u003E= 8 caracteres.\n",
        "- Contén maiúscula e número.\n",
        "- Usa walrus para non repetir len(contrasinal)."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "ac80b254",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"

while (pwd := input("Introduce una contraseña: ")) != "":

    if (longitud := len(pwd) >= 8 and (mayus := any(c.isupper() for c in pwd)) and (num :=any(c.isdigit() for c in pwd))):
        print(f"contraseña valida (longitud: {len(pwd)})")
        break
    else:
        print(" la contarseña debe tener")
        print("- al menos 8 caracteres")
        print("- Una letra mayuscula")
        print("- Un número")

print("Fin")



      ]
    },
    {
      "cell_type": "markdown",
      "id": "a85a2636",
      "metadata": {

      },
      "source": [
        "---\n",
        "\n",
        "### Exercicio 9: Combinación de Operadores\n",
        "\n",
        "Calculadora de IMC (xa a fixemos pero desta volta é máis completa):\n",
        "- peso / altura²\n",
        "- Clasifica segundo táboa OMS\n",
        "- Baixo peso: \u003C 18.5\n",
        "- Normal: 18.5 - 24.9\n",
        "- Sobrepeso: 25 - 29.9\n",
        "- Obesidade: \u003E= 30\n",
        "- Usa operadores de comparación e lóxicos\n",
        "- Opcional: walrus para evitar repetir cálculo"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "9e5a94e9",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"

print("Vamos a calcular tu masa corporal")

peso = float(input("¿Cuál es tu peso en kg?: "))
estatura = float(input("¿Cuál es tu estatura en metros?: "))

if (imc := peso / estatura**2) < 18.5:
    print("Bajo peso")
elif imc >= 18.5 and imc <= 24.9:
    print("Peso normal")
elif imc >= 25 and imc <= 29.9:
    print("Sobrepeso")
else:
    print("Obesidad")

print(f"Tu índice de masa corporal es: {imc:.2f}")


      ]
    },
    {
      "cell_type": "markdown",
      "id": "73a8333b",
      "metadata": {

      },
      "source": [
        "---\n",
        "\n",
        "### Exercicio 10: Analizador de Texto\n",
        "\n",
        "Analiza un texto introducido polo usuario:\n",
        "1. Lonxitude.\n",
        "2. Se contén certas palabras.\n",
        "3. Conta vogais.\n",
        "4. Verifica se é palíndromo.\n",
        "5. Verifica se texto é `None`.\n",
        "6. Concatena."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "423b1365",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"

texto=input("introduce una frase:")


longitud= len(texto)
print({f"la frase tiene  {longitud}  caracteres"})

palabras= ["hola" , "adios"]
for p in palabras:
    if p in texto:
        print(f"la palabra {p} esta en la frase {texto}")
    else:
        print(f"la palabra {p} no esta en la frase {texto}")

#contar vocales
vocales= "aeiou"
contador=0

for letra in texto:
    if letra in vocales :
        contador += 1

print(f"hay {contador} vocales")

#

#verfificar si es NONE
print(f"5. Texto es None: {texto is None}")



      ]
    },
    {
      "cell_type": "markdown",
      "id": "237bcedc",
      "metadata": {

      },
      "source": [
        "---\n",
        "\n",
        "### Xogo de Adiviñanza\n",
        "\n",
        "Xogo onde:\n",
        "- Número secreto aleatorio (1-100).\n",
        "- Aportar Pistas (\"é maior\", \"é menor\").\n",
        "- Contador de intentos.\n",
        "- Utiliza Walrus.\n",
        "- Preguntar se se quere xogar outra vez."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "a2682b0c",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"
import random

jugar = "si"

while jugar == "si":
    numero_secreto = random.randint(1, 100)
    contador = 0

    print("Vamos a jugar adivinando un numero entre 1 y 100")

    while (numero := int(input("Ingresa un número: "))) != numero_secreto:
        contador += 1

        if numero > numero_secreto:
            print("El número es mayor que el número secreto")
        else:
            print("El número es menor que el número secreto")

    contador += 1
    print(f"¡Correcto! Número: {numero_secreto}")
    print(f"Intentos: {contador}")

    jugar = input("¿Deseas jugar de nuevo? [si/no]: ")

           ]
    },
    {
      "cell_type": "markdown",
      "id": "c16ddc6b",
      "metadata": {

      },
      "source": [
        "---\n",
        "\n",
        "### Validador de Email\n",
        "\n",
        "Valida email con:\n",
        "- Que conteña unha `@`.\n",
        "- Que conteña un `.` despois da `@`.\n",
        "- Lonxitude \u003E= 5.\n",
        "- Non conteña espazos en branco.\n",
        "- Dominio pertenza a unha lista de dominios válida."
      ]
    },
    {
      "cell_type": "code",
      "execution_count": null,
      "id": "a847f138",
      "metadata": {

      },
      "outputs": [],
      "source": [
        "# Pon a túa solución aquí"

dominios_validos = ["gmail.com", "outlook.com", "hotmail.com, yahoo.com"]

while True:
    email = input("Introduce un email: ")

    # Lonxitude mínima
    if len(email) < 4:
        print(" Email demasiado corto")
        continue

    # Espazos
    if " " in email:
        print(" No puede contener espacios")
        continue

    # Arroba
    if "@" not in email:
        print(" Falta @")
        continue

    partes = email.split("@")

    if len(partes) != 2:
        print(" Debe tener una sola @")
        continue

    dominio = partes[1]

    # Punto después de la @
    if "." not in dominio:
        print(" El dominio debe tener un punto")
        continue

    # Dominio válido
    if dominio not in dominios_validos:
        print(" Dominio no válido")
        continue

    print(" Email válido")
    break





      ]
    }
  ],
  "metadata": {
    "language_info": {
      "name": "python"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 22
#       1 {
#       2   "cells": [
#       3     {
#       4       "cell_type": "markdown",
#       5       "id": "d86f5cdb",
#       6       "metadata": {
#       7
#       8       },
#       9       "source": [
#      10         "### Exercicio 1: Operadores Aritméticos\n",
#      11         "\n",
#      12         "Calcula a área e perímetro dun rectángulo:\n",
#      13         "- Pide ao usuario base e altura.\n",
#      14         "- Calcula área.\n",
#      15         "- Calcula perímetro.\n",
#      16         "- Utiliza `//` e `%`.\n",
#      17         "- Amosa os resultados utilizando diferentes formatos de cadeas."
#      18       ]
#      19     },
#      20     {
#      21       "cell_type": "code",
# ---> 22       "execution_count": null,
#      23       "id": "3771e266",
# ...
